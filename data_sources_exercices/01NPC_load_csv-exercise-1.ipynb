# %% [markdown]
# # Load CSV files. Exercise 1

# %% [markdown]
# Use the dataset about Liga (1919-2020) champions: "La_Liga_Winners.csv"
#
# https://www.kaggle.com/kishan305/spanish-football-la-liga-champions

# %%
# import pandas library
import pandas as pd

# %%
# load the CSV file into a DataFrame
df = pd.read_csv("../datasets/La_Liga_Winners.csv")

# %%
# show DataFrame
df
# Out:
#      Season            Winner          Runner-up      Third Place  \
# 0      1929        Barcelona        Real Madrid   Athletic Bilbao
# 1   1929–30  Athletic Bilbao          Barcelona            Arenas
# 2   1930–31  Athletic Bilbao   Racing Santander     Real Sociedad
# 3   1931–32      Real Madrid    Athletic Bilbao         Barcelona
# 4   1932–33      Real Madrid    Athletic Bilbao          Espanyol
# ..      ...               ...                ...              ...
# 87  2015–16        Barcelona        Real Madrid   Atlético Madrid
# 88  2016–17     Real Madrid           Barcelona   Atlético Madrid
# 89  2017–18        Barcelona    Atlético Madrid       Real Madrid
# 90  2018–19        Barcelona    Atlético Madrid       Real Madrid
# 91  2019–20      Real Madrid          Barcelona   Atlético Madrid
#
#              Top Scorer Top scorer's club(s) Goals
# 0        Paco Bienzobas        Real Sociedad    14
# 1   Guillermo Gorostiza      Athletic Bilbao    19
# 2   Agustín Sauto Arana      Athletic Bilbao    27
# 3   Guillermo Gorostiza      Athletic Bilbao    12
# 4       Manuel Olivares          Real Madrid    16
# ..                  ...                  ...   ...
# 87          Luis Suárez            Barcelona    40
# 88         Lionel Messi            Barcelona    37
# 89         Lionel Messi            Barcelona    34
# 90         Lionel Messi            Barcelona    36
# 91         Lionel Messi            Barcelona    25
#
# [92 rows x 7 columns]

# %%
# show first lines of the DataFrame
df.head()
# Out:
#     Season            Winner          Runner-up      Third Place  \
# 0     1929        Barcelona        Real Madrid   Athletic Bilbao
# 1  1929–30  Athletic Bilbao          Barcelona            Arenas
# 2  1930–31  Athletic Bilbao   Racing Santander     Real Sociedad
# 3  1931–32      Real Madrid    Athletic Bilbao         Barcelona
# 4  1932–33      Real Madrid    Athletic Bilbao          Espanyol
#
#             Top Scorer Top scorer's club(s) Goals
# 0       Paco Bienzobas        Real Sociedad    14
# 1  Guillermo Gorostiza      Athletic Bilbao    19
# 2  Agustín Sauto Arana      Athletic Bilbao    27
# 3  Guillermo Gorostiza      Athletic Bilbao    12
# 4      Manuel Olivares          Real Madrid    16

# %%
# show the 3 first lines of the DataFrame
df.head(3)
# Out:
#     Season            Winner          Runner-up      Third Place  \
# 0     1929        Barcelona        Real Madrid   Athletic Bilbao
# 1  1929–30  Athletic Bilbao          Barcelona            Arenas
# 2  1930–31  Athletic Bilbao   Racing Santander     Real Sociedad
#
#             Top Scorer Top scorer's club(s) Goals
# 0       Paco Bienzobas        Real Sociedad    14
# 1  Guillermo Gorostiza      Athletic Bilbao    19
# 2  Agustín Sauto Arana      Athletic Bilbao    27

# %%
# show the last lines of the DataFrame
df.tail()
# Out:
#      Season         Winner         Runner-up      Third Place    Top Scorer  \
# 87  2015–16     Barcelona       Real Madrid   Atlético Madrid   Luis Suárez
# 88  2016–17  Real Madrid          Barcelona   Atlético Madrid  Lionel Messi
# 89  2017–18     Barcelona   Atlético Madrid       Real Madrid  Lionel Messi
# 90  2018–19     Barcelona   Atlético Madrid       Real Madrid  Lionel Messi
# 91  2019–20   Real Madrid         Barcelona   Atlético Madrid  Lionel Messi
#
#    Top scorer's club(s) Goals
# 87            Barcelona    40
# 88            Barcelona    37
# 89            Barcelona    34
# 90            Barcelona    36
# 91            Barcelona    25

# %%
# show the 8 last lines of the DataFrame
df.tail(8)
# Out:
#      Season            Winner         Runner-up      Third Place  \
# 84  2012–13        Barcelona       Real Madrid   Atlético Madrid
# 85  2013–14  Atlético Madrid         Barcelona       Real Madrid
# 86  2014–15       Barcelona        Real Madrid   Atlético Madrid
# 87  2015–16        Barcelona       Real Madrid   Atlético Madrid
# 88  2016–17     Real Madrid          Barcelona   Atlético Madrid
# 89  2017–18        Barcelona   Atlético Madrid       Real Madrid
# 90  2018–19        Barcelona   Atlético Madrid       Real Madrid
# 91  2019–20      Real Madrid         Barcelona   Atlético Madrid
#
#            Top Scorer Top scorer's club(s) Goals
# 84       Lionel Messi            Barcelona    46
# 85  Cristiano Ronaldo          Real Madrid    31
# 86  Cristiano Ronaldo          Real Madrid    48
# 87        Luis Suárez            Barcelona    40
# 88       Lionel Messi            Barcelona    37
# 89       Lionel Messi            Barcelona    34
# 90       Lionel Messi            Barcelona    36
# 91       Lionel Messi            Barcelona    25

# %%
# show the "shape" of the DataFrame (files x rows)
df.shape
# Out:
# (92, 7)

# %%
# show the main statistics
df.describe()
# Out:
#        Season        Winner   Runner-up      Third Place    Top Scorer  \
# count      92            92          92               92            92
# unique     92            14          15               21            54
# top      1929  Real Madrid   Barcelona   Atlético Madrid  Lionel Messi
# freq        1            30          26               14             7
#
#        Top scorer's club(s) Goals
# count                    92    92
# unique                   28    28
# top             Real Madrid    27
# freq                     23    10

# %%
# select the 'Winner' column as a Series
df["Winner"]
# Out:
# 0           Barcelona
# 1     Athletic Bilbao
# 2     Athletic Bilbao
# 3         Real Madrid
# 4         Real Madrid
#             ...
# 87          Barcelona
# 88       Real Madrid
# 89          Barcelona
# 90          Barcelona
# 91        Real Madrid
# Name: Winner, Length: 92, dtype: object

# %%
# show the type of the previous selection
type(df["Winner"])
# Out:
# pandas.core.series.Series

# %%
# Another way of selecting a column:  dataframe_name.column_name
df.Winner
# Out:
# 0           Barcelona
# 1     Athletic Bilbao
# 2     Athletic Bilbao
# 3         Real Madrid
# 4         Real Madrid
#             ...
# 87          Barcelona
# 88       Real Madrid
# 89          Barcelona
# 90          Barcelona
# 91        Real Madrid
# Name: Winner, Length: 92, dtype: object

# %%
# show the type of the previous selection
type(df.Winner)
# Out:
# pandas.core.series.Series

# %%
# select the 'Winner' column as a DataFrame
df[["Winner"]]
# Out:
#               Winner
# 0         Barcelona
# 1   Athletic Bilbao
# 2   Athletic Bilbao
# 3       Real Madrid
# 4       Real Madrid
# ..               ...
# 87        Barcelona
# 88     Real Madrid
# 89        Barcelona
# 90        Barcelona
# 91      Real Madrid
#
# [92 rows x 1 columns]

# %%
# show the type of the previous selection
type(df[["Winner"]])

# %%
# select many columns: 'Top Scorer' and  'Goals'
df[["Top Scorer", "Goals"]]
# Out:
#              Top Scorer Goals
# 0        Paco Bienzobas    14
# 1   Guillermo Gorostiza    19
# 2   Agustín Sauto Arana    27
# 3   Guillermo Gorostiza    12
# 4       Manuel Olivares    16
# ..                  ...   ...
# 87          Luis Suárez    40
# 88         Lionel Messi    37
# 89         Lionel Messi    34
# 90         Lionel Messi    36
# 91         Lionel Messi    25
#
# [92 rows x 2 columns]

# %%
# show the type of the previous selection
type(df[["Top Scorer", "Goals"]])

# %%
# show the argument type you have passed to the DataFrame to get the previous selection (['column1','column2'])
print(type(["Top Scorer", "Goals"]))
# Out:
# <class 'list'>
