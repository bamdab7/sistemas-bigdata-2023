# %% [markdown]
# # Pandas DataFrames. Selecting rows and cols. Exercise 3
#
# Pandas documentation: https://pandas.pydata.org/docs/index.html
#
# Pandas API reference: https://pandas.pydata.org/docs/reference/index.html#api

# %%
#import pandas library
import pandas as pd

# %% [markdown]
# ### Dataset: Countries of the world
# https://www.kaggle.com/datasets/fernandol/countries-of-the-world
#
# More info about the dataset columns in kaggle.
#
# *Note*: you can find the dataset in this repo: countries_of_the_world.csv

# %%
# Open the dataset from the local filesystem
df_countries = pd.read_csv(("../datasets/countries_of_the_world.csv"))
df_countries
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0            647500                       48,0                         0,00
# 1             28748                      124,6                         1,26
# 2           2381740                       13,8                         0,04
# 3               199                      290,4                        58,29
# 4               468                      152,1                         0,00
# ..              ...                        ...                          ...
# 222            5860                      419,9                         0,00
# 223          266000                        1,0                         0,42
# 224          527970                       40,6                         0,36
# 225          752614                       15,3                         0,00
# 226          390580                       31,3                         0,00
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0           23,06                             163,07               700.0
# 1           -4,93                              21,52              4500.0
# 2           -0,39                                 31              6000.0
# 3          -20,71                               9,27              8000.0
# 4             6,6                               4,05             19000.0
# ..            ...                                ...                 ...
# 222          2,98                              19,62               800.0
# 223           NaN                                NaN                 NaN
# 224             0                               61,5               800.0
# 225             0                              88,29               800.0
# 226             0                              67,69              1900.0
#
#     Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0           36,0               3,2      12,13      0,22     87,65       1
# 1           86,5              71,2      21,09      4,42     74,49       3
# 2           70,0              78,1       3,22      0,25     96,53       1
# 3           97,0             259,5         10        15        75       2
# 4          100,0             497,2       2,22         0     97,78       3
# ..           ...               ...        ...       ...       ...     ...
# 222          NaN             145,2       16,9     18,97     64,13       3
# 223          NaN               NaN       0,02         0     99,98       1
# 224         50,2              37,2       2,78      0,24     96,98       1
# 225         80,6               8,2       7,08      0,03      92,9       2
# 226         90,7              26,8       8,32      0,34     91,34       2
#
#     Birthrate Deathrate Agriculture Industry Service
# 0        46,6     20,34        0,38     0,24    0,38
# 1       15,11      5,22       0,232    0,188   0,579
# 2       17,14      4,61       0,101      0,6   0,298
# 3       22,46      3,27         NaN      NaN     NaN
# 4        8,71      6,25         NaN      NaN     NaN
# ..        ...       ...         ...      ...     ...
# 222     31,67      3,92        0,09     0,28    0,63
# 223       NaN       NaN         NaN      NaN     0,4
# 224     42,89       8,3       0,135    0,472   0,393
# 225        41     19,93        0,22     0,29   0,489
# 226     28,01     21,84       0,179    0,243   0,579
#
# [227 rows x 20 columns]

# %%
# Select columns Country, Region and Population
df_countries[["Country", "Region", "Population"]]
# Out:
#              Country                               Region  Population
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
# [227 rows x 3 columns]

# %%
# Select the 4 first rows of the dataframe, columns Country, Population and Area
df_countries[["Country", "Population", "Area (sq. mi.)"]].head(4)
# Out:
#            Country  Population  Area (sq. mi.)
# 0     Afghanistan     31056997          647500
# 1         Albania      3581655           28748
# 2         Algeria     32930091         2381740
# 3  American Samoa        57794             199

# %%
# Show column names
df_countries.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
# Select the last 6 rows of the dataset, columns: country, literacy and Phones
df_countries[["Country", "Literacy (%)", "Phones (per 1000)"]].tail(6)
# Out:
#                 Country Literacy (%) Phones (per 1000)
# 221  Wallis and Futuna          50,0             118,6
# 222          West Bank           NaN             145,2
# 223     Western Sahara           NaN               NaN
# 224              Yemen          50,2              37,2
# 225             Zambia          80,6               8,2
# 226           Zimbabwe          90,7              26,8

# %%
# Select the two firts rows using loc or iloc
df_countries.loc[0:1]
# Out:
#         Country                               Region  Population  \
# 0  Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1      Albania   EASTERN EUROPE                          3581655
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# 1     15,11      5,22       0,232    0,188   0,579

# %%
# Select the fifth row
df_countries.loc[[4]]
# Out:
#     Country                               Region  Population  Area (sq. mi.)  \
# 4  Andorra   WESTERN EUROPE                            71201             468
#
#   Pop. Density (per sq. mi.) Coastline (coast/area ratio) Net migration  \
# 4                      152,1                         0,00           6,6
#
#   Infant mortality (per 1000 births)  GDP ($ per capita) Literacy (%)  \
# 4                               4,05             19000.0        100,0
#
#   Phones (per 1000) Arable (%) Crops (%) Other (%) Climate Birthrate  \
# 4             497,2       2,22         0     97,78       3      8,71
#
#   Deathrate Agriculture Industry Service
# 4      6,25         NaN      NaN     NaN

# %%
# Select data from Algeria (using loc)
df_countries2 = pd.read_csv(("../datasets/countries_of_the_world.csv"),index_col='Country')
df_countries2.loc['Algeria']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Algeria'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/xuwira36/code/sistemas-bigdata-2023/data_sources/03NPC_dataframe_selection-exercise-3.ipynb Celda 11 line 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/xuwira36/code/sistemas-bigdata-2023/data_sources/03NPC_dataframe_selection-exercise-3.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Select data from Algeria (using loc)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/xuwira36/code/sistemas-bigdata-2023/data_sources/03NPC_dataframe_selection-exercise-3.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> df_countries2 = pd.read_csv(("../datasets/countries_of_the_world.csv"),index_col='Country')
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/xuwira36/code/sistemas-bigdata-2023/data_sources/03NPC_dataframe_selection-exercise-3.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> df_countries2.loc['Algeria']
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File ~/miniconda3/envs/sistemas/lib/python3.12/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Algeria'

# %%
# Save data about Albania in a new dataframe variable
# Then show the new dataframe

# %%
# Create a new dataframe calle datos_10_paises 
# columns: Country, Population and Climate 
# rows: the ten first ones
# Then show the new dataframe

# %%
# Load the dataframe again using country names as index

# %%
# Show 5 random rows

# %%
# Show data about France (use indexes)


# Note: If you have problems with indexes, take a look to the CSV file directly ;-)

# %%
# Create a new dataframe with data about Spain
# Columns: Population, Area, Climate, Birthrate and Deathrate

# %%
# Select all data from these countries: France, Germany and Spain

# %%
# Select a range of rows
# Select rows from 10 to 20 (not included)

# %%
# Select rows from Spain to Uruguay
# Show only Population and Density columns
